# %% [markdown]
# # **Imports**

# %%
# Imports
import os
from ultralytics import YOLO
from IPython.display import display, Image
from IPython import display
import torch
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Clear the display
display.clear_output()

# Enable yolo checks
# !yolo mode = checks
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\Sujal\AppData\Roaming\Python\Python311\Scripts\yolo.exe\__main__.py", line 7, in <module>
#   File "C:\Users\Sujal\AppData\Roaming\Python\Python311\site-packages\ultralytics\cfg\__init__.py", line 649, in entrypoint
#     raise ValueError(f"Invalid 'mode={mode}'. Valid modes are {MODES}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'mode=<module 'ultralytics.utils.checks' from 'C:\\Users\\Sujal\\AppData\\Roaming\\Python\\Python311\\site-packages\\ultralytics\\utils\\checks.py'>'. Valid modes are {'train', 'benchmark', 'predict', 'val', 'export', 'track'}.
#
#     Arguments received: ['yolo', 'mode', '=', 'checks']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of {'classify', 'pose', 'obb', 'detect', 'segment'}
# ...

# %% [markdown]
# # **Loading YOLOv8 Model**

# %%
# Create model using pretrained weights
model = YOLO("yolov8n.yaml").load("yolov8n.pt")
# Out:
# Transferred 355/355 items from pretrained weights

# %% [markdown]
# # **Train Model**

# %%
# Train the model
results = model.train(data="./data.yaml", epochs=5, imgsz = 640)
# Out:
# New https://pypi.org/project/ultralytics/8.2.87 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.58  Python-3.11.4 torch-2.3.1+cpu CPU (11th Gen Intel Core(TM) i5-1135G7 2.40GHz)
# ...

# %%
# Evaluate the model
metrics = model.val()
# Out:
# Ultralytics YOLOv8.2.58  Python-3.11.4 torch-2.3.1+cpu CPU (11th Gen Intel Core(TM) i5-1135G7 2.40GHz)
# YOLOv8n summary (fused): 168 layers, 3,006,623 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning C:\Users\Sujal\Desktop\Traffic Detection Project\Traffic Detection Project\Traffic Detection Project\datasets\valid\labels.cache... 549 images, 8 backgrounds, 0 corrupt: 100%|██████████| 549/549 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 35/35 [02:37<00:00,  4.49s/it]
#                    all        549       6270        0.8      0.761      0.835      0.578
#                bicycle        189        250      0.862       0.74      0.809      0.601
#                    bus         81        108      0.706      0.889      0.913      0.765
#                    car        520       3842      0.819      0.928      0.945      0.697
# ...

# %% [markdown]
# # **Visualize Results**

# %%
# Precision - Recall curve
Image(filename = r"C:\Users\Sujal\Desktop\Traffic Detection Project\Traffic Detection Project\Traffic Detection Project\runs\detect\train\PR_curve.png", width = 600)

# %%
# Confusion matrix
Image(filename = r"C:\Users\Sujal\Desktop\Traffic Detection Project\Traffic Detection Project\Traffic Detection Project\runs\detect\train\confusion_matrix.png", width = 600)

# %%
# Object detected image
Image(filename = r"C:\Users\Sujal\Desktop\Traffic Detection Project\Traffic Detection Project\Traffic Detection Project\runs\detect\train2\val_batch1_pred.jpg", width = 600)

# %%
# Results
Image(filename = r"C:\Users\Sujal\Desktop\Traffic Detection Project\Traffic Detection Project\Traffic Detection Project\runs\detect\train\results.png", width = 600)

# %% [markdown]
# # **Model Evaluation**

# %%
# Model validation
val_results = model.val(model = r"C:\Users\Sujal\Desktop\Traffic Detection Project\Traffic Detection Project\Traffic Detection Project\runs\detect\train\weights\best.pt", data="./data.yaml")
# Out:
# Ultralytics YOLOv8.2.58  Python-3.11.4 torch-2.3.1+cpu CPU (11th Gen Intel Core(TM) i5-1135G7 2.40GHz)
# val: Scanning C:\Users\Sujal\Desktop\Traffic Detection Project\Traffic Detection Project\Traffic Detection Project\datasets\valid\labels.cache... 549 images, 8 backgrounds, 0 corrupt: 100%|██████████| 549/549 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 35/35 [02:36<00:00,  4.48s/it]
#                    all        549       6270        0.8      0.761      0.835      0.578
#                bicycle        189        250      0.862       0.74      0.809      0.601
#                    bus         81        108      0.706      0.889      0.913      0.765
#                    car        520       3842      0.819      0.928      0.945      0.697
#              motorbike        331       1238       0.86      0.716      0.821       0.48
# ...
